# %%
import pandas as pd
import seaborn as sns
from save_stats import hfile, sfile

# %%
hdf = pd.read_parquet(hfile)
sdf = pd.read_parquet(sfile)
hdf['amount_btc'] = hdf['amount']/100e6
hdf['avg_outputs_per_tx'] = hdf['num_outputs'] / hdf['num_txs']
sdf['amount_btc'] = sdf['amount']/100e6

# %%
hdf.head(2)
# Out:
#    height      amount  num_outputs  num_txs  amount_btc  avg_outputs_per_tx
# 0  778001  2894619930          483      296   28.946199            1.631757
# 1  778002  2937798476          499      377   29.377985            1.323607

# %%
sdf.head(2)
# Out:
#    height script_type     amount  num_outputs  amount_btc
# 0  778001       p2pkh   69449775          120    0.694498
# 1  778001        p2sh  346029831          127    3.460298

# %%
sns.set(rc={'figure.figsize':(15, 5)})
sns.lineplot(data=hdf, x='height', y='num_txs')
# Out:
# <Axes: xlabel='height', ylabel='num_txs'>

# %%
sns.lineplot(data=hdf, x='height', y='num_outputs')
# Out:
# <Axes: xlabel='height', ylabel='num_outputs'>

# %%
sns.lineplot(data=hdf, x='height', y='avg_outputs_per_tx')
# Out:
# <Axes: xlabel='height', ylabel='avg_outputs_per_tx'>

# %%
sns.lineplot(data=hdf, x='height', y='amount_btc')
# Out:
# <Axes: xlabel='height', ylabel='amount_btc'>

# %%
sns.lineplot(data=sdf, x='height', y='num_outputs', hue='script_type')
# Out:
# <Axes: xlabel='height', ylabel='num_outputs'>

# %%
sns.lineplot(data=sdf, x='height', y='amount_btc', hue='script_type')
# Out:
# <Axes: xlabel='height', ylabel='amount_btc'>
